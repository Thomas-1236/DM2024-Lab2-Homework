# %% [markdown]
# ### Student Information
# Name:洪辰諭
#
# Student ID:G12360023
#
# GitHub ID:
#
# Kaggle name:
#
# Kaggle private scoreboard snapshot:

# %% [markdown]
# ---

# %% [markdown]
# ### Instructions

# %% [markdown]
# 1. First: __This part is worth 30% of your grade.__ Do the **take home exercises** in the [DM2024-Lab2-master Repo](https://github.com/didiersalazar/DM2024-Lab2-Master). You may need to copy some cells from the Lab notebook to this notebook.
#
#
# 2. Second: __This part is worth 30% of your grade.__ Participate in the in-class [Kaggle Competition](https://www.kaggle.com/competitions/dm-2024-isa-5810-lab-2-homework) regarding Emotion Recognition on Twitter by this link: https://www.kaggle.com/competitions/dm-2024-isa-5810-lab-2-homework. The scoring will be given according to your place in the Private Leaderboard ranking:
#     - **Bottom 40%**: Get 20% of the 30% available for this section.
#
#     - **Top 41% - 100%**: Get (0.6N + 1 - x) / (0.6N) * 10 + 20 points, where N is the total number of participants, and x is your rank. (ie. If there are 100 participants and you rank 3rd your score will be (0.6 * 100 + 1 - 3) / (0.6 * 100) * 10 + 20 = 29.67% out of 30%.)
#     Submit your last submission **BEFORE the deadline (Nov. 26th, 11:59 pm, Tuesday)**. Make sure to take a screenshot of your position at the end of the competition and store it as '''pic0.png''' under the **img** folder of this repository and rerun the cell **Student Information**.
#
#
# 3. Third: __This part is worth 30% of your grade.__ A report of your work developing the model for the competition (You can use code and comment on it). This report should include what your preprocessing steps, the feature engineering steps and an explanation of your model. You can also mention different things you tried and insights you gained.
#
#
# 4. Fourth: __This part is worth 10% of your grade.__ It's hard for us to follow if your code is messy :'(, so please **tidy up your notebook**.
#
#
# Upload your files to your repository then submit the link to it on the corresponding e-learn assignment.
#
# Make sure to commit and save your changes to your repository __BEFORE the deadline (Nov. 26th, 11:59 pm, Tuesday)__.

# %%
### Begin Assignment Here

# %%
# Exercise 1
# clean train_df and test_df
train_df['cleaned_text'] = train_df['text'].str.replace(r'[^a-zA-Z\s]', '', regex=True)
test_df['cleaned_text'] = test_df['text'].str.replace(r'[^a-zA-Z\s]', '', regex=True)

# count
count_vect_train = CountVectorizer(stop_words='english')
word_counts_train = count_vect_train.fit_transform(train_df['cleaned_text'])

term_frequencies_train = word_counts_train.sum(axis=0).A1
terms_train = count_vect_train.get_feature_names_out()

df_plotly_train = pd.DataFrame({'Term': terms_train, 'Frequency': term_frequencies_train})

# choose the top 30
df_top30_train = df_plotly_train.sort_values(by='Frequency', ascending=False).head(30)

# plot pic
fig_train = px.bar(df_top30_train, x='Term', y='Frequency', height=600, title='Top 30 Word Frequencies (Train Data)')
fig_train.update_layout(xaxis_tickangle=-90)
fig_train.show()

# test df
count_vect_test = CountVectorizer(stop_words='english')
word_counts_test = count_vect_test.fit_transform(test_df['cleaned_text'])

term_frequencies_test = word_counts_test.sum(axis=0).A1
terms_test = count_vect_test.get_feature_names_out()

df_plotly_test = pd.DataFrame({'Term': terms_test, 'Frequency': term_frequencies_test})
df_top30_test = df_plotly_test.sort_values(by='Frequency', ascending=False).head(30)

fig_test = px.bar(df_top30_test, x='Term', y='Frequency', height=600, title='Top 30 Word Frequencies (Test Data)')
fig_test.update_layout(xaxis_tickangle=-90)
fig_test.show()

# %%
#Exercise 2 
from sklearn.feature_extraction.text import TfidfVectorizer

# set TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer(max_features=1000, tokenizer=nltk.word_tokenize,token_pattern=None)
tfidf_vectorizer.fit(train_df['text'])
train_data_tfidf_features = tfidf_vectorizer.transform(train_df['text'])

# print the shape 
print("Shape :", train_data_tfidf_features.shape)

# print feature names 100 to 110
feature_names = tfidf_vectorizer.get_feature_names_out()
print("Feature names:", feature_names[100:110])
# Out:
# Shape : (3613, 1000)
# Feature names: ['awful' 'b' 'baby' 'back' 'bad' 'ball' 'balls' 'bb18' 'bc' 'bday']

# %% [markdown]
# Exercise 3
# We can see the Y is true label ,the X is predicted label.So the diagonal elements means we predicted correctly.The 'anger'has 57 correct，‘fear’ has 76 correct,'joy',the 'joy'has 56 correct,the 'sadness'has 47 correct.We get average-level forecasts.

# %%
# Exercise 4 
from sklearn.naive_bayes import MultinomialNB
nb_model = MultinomialNB()

## training!
nb_model = nb_model.fit(X_train, y_train)

## predict!
y_train_pred = nb_model.predict(X_train)
y_test_pred = nb_model.predict(X_test)

## so we get the pred result
print(y_test_pred[:10])

acc_train = accuracy_score(y_true=y_train, y_pred=y_train_pred)
acc_test = accuracy_score(y_true=y_test, y_pred=y_test_pred)

print('training accuracy: {}'.format(round(acc_train, 2)))
print('testing accuracy: {}'.format(round(acc_test, 2)))

cm = confusion_matrix(y_true=y_test, y_pred=y_test_pred) 
print(cm)

my_tags = ['anger', 'fear', 'joy', 'sadness']
plot_confusion_matrix(cm, classes=my_tags, title='Confusion matrix')
# Out:
# ['joy' 'joy' 'joy' 'sadness' 'anger' 'fear' 'sadness' 'sadness' 'fear'
#  'joy']
# training accuracy: 0.79
# testing accuracy: 0.7
# [[55 15  5  9]
#  [ 9 85  5 11]
#  [11  6 56  6]
#  [12 10  6 46]]

# %% [markdown]
# # Exercise 5
# I think the Naive Bayes get a better result,we can find Naive Bayes get better on test.I think Decision Tree has some problem with over fitting,because it ge higt point on train,but low point on test.

# %% [markdown]
# # Exercise 6
# We can see in the two picture train get better when epoch go up,but the test did not ,the test go down,i think it may be has problem with overfitting,we need to deal with it.

# %%
#Exercise 6 
# Plot training and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linestyle='--')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Plot training and validation loss
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss', linestyle='--')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Exercise 7
# We can calculate the frequency of each word to train our model.We can do weighted average,it may be have a better result.

# %%
# Exercise 8
word_list = ['happy', 'angry','sad','fear']

topn = 15
happy_words = ['happy'] + [word_ for word_, sim_ in w2v_google_model.most_similar('happy', topn=topn)]
angry_words = ['angry'] + [word_ for word_, sim_ in w2v_google_model.most_similar('angry', topn=topn)]  
sad_words = ['sad'] + [word_ for word_, sim_ in w2v_google_model.most_similar('sad', topn=topn)]
fear_words = ['fear'] + [word_ for word_, sim_ in w2v_google_model.most_similar('fear', topn=topn)] 

print('happy_words: ', happy_words)
print('angry_words: ', angry_words)
print('sad_words: ', sad_words)
print('fear_words: ', fear_words)

target_words = happy_words + angry_words + sad_words + fear_words
print('\ntarget words: ')
print(target_words)

print('\ncolor list:')
cn = topn + 1
color = ['b'] * cn + ['g'] * cn + ['r'] * cn + ['y'] * cn
print(color)


## w2v model
model = w2v_google_model

## prepare training word vectors
size = 200
target_size = len(target_words)
all_word = list(model.index_to_key)
word_train = target_words + all_word[:size]
X_train = model[word_train]

## t-SNE model
tsne = TSNE(n_components=2, metric='cosine', random_state=28)

## training
X_tsne = tsne.fit_transform(X_train)

## plot the result
plt.figure(figsize=(7.5, 7.5), dpi=115)
plt.scatter(X_tsne[:target_size, 0], X_tsne[:target_size, 1], c=color)
for label, x, y in zip(target_words, X_tsne[:target_size, 0], X_tsne[:target_size, 1]):
    plt.annotate(label, xy=(x,y), xytext=(0,0),  textcoords='offset points')
plt.show()


## w2v model
model = w2v_google_model

## prepare training word vectors
size = 200
target_size = len(target_words)
all_word = list(model.index_to_key)
word_train = target_words + all_word[:size]
X_train = model[word_train]

## UMAP model
umap_model = umap.UMAP(n_components=2, metric='cosine', random_state=28)

## training
X_umap = umap_model.fit_transform(X_train)

## plot the result
plt.figure(figsize=(7.5, 7.5), dpi=115)
plt.scatter(X_umap[:target_size, 0], X_umap[:target_size, 1], c=color)
for label, x, y in zip(target_words, X_umap[:target_size, 0], X_umap[:target_size, 1]):
    plt.annotate(label, xy=(x,y), xytext=(0,0),  textcoords='offset points')
plt.show()


#the umap get closer than t-sne
# Out:
# happy_words:  ['happy', 'glad', 'pleased', 'ecstatic', 'overjoyed', 'thrilled', 'satisfied', 'proud', 'delighted', 'disappointed', 'excited', 'happier', 'Said_Hirschbeck', 'elated', 'thankful', 'unhappy']
# angry_words:  ['angry', 'irate', 'enraged', 'indignant', 'incensed', 'annoyed', 'agitated', 'frustrated', 'furious', 'unhappy', 'outraged', 'livid', 'irritated', 'exasperated', 'angrier', 'Angry']
# sad_words:  ['sad', 'saddening', 'Sad', 'saddened', 'heartbreaking', 'disheartening', 'Meny_Friedman', 'parishioner_Pat_Patello', 'saddens_me', 'distressing', 'reminders_bobbing', 'Turkoman_Shiites', 'saddest', 'unfortunate', 'sorry', 'bittersweet']
# fear_words:  ['fear', 'fearful', 'fears', 'Fear', 'fearing', 'worry', 'dread', 'feared', 'anxiety', 'apprehension', 'afraid', 'worries', 'concern', 'distrust', 'worried', 'Fearful']
#
# target words:
# ...

# %% [markdown]
# # Exercise 9
# We also have assistant and system.The assistant is use to answer our question.The system is use to tell the machine to be which person and how he answer us,like we let him become a programmer wo answer our question.

# %%
# Exercise 10 
response3 = ollama.chat(model='llava-phi3', messages=[
    {
        'role': 'user',
        'content': 'What is this image about?',
        'images': ['./pics/bike.jpg'] #Image with the cat
    },
])

display(Markdown(response3['message']['content']))
# Out:
# This image captures a moment of tranquility, featuring a white folding bicycle with black accents and red rims. The bicycle is in a state of rest, leaning against a stark white background that contrasts with its vibrant colors. Its front wheel is slightly turned to the left, suggesting it's ready for an imminent journey.
#
# The frame of the bicycle is adorned with black accents and red rims, adding a touch of elegance to its simplicity. The seat and handlebars mirror this color scheme, creating a harmonious balance in design. A small black water bottle attached to the frame hints at long journeys spent away from home.
#
# The image also contains text that reads "大萬里斯-17号-WITH-KICKSTAR", but without additional context, its meaning remains unclear. Overall, this image paints a picture of anticipation and adventure, embodied in the form of a simple, yet stylish bicycle.

# %% [markdown]
# yes,it is accurate,I gave him an electric-assisted bicycle and he described it successfully。

# %%
#  Exercise 11 
from langchain.document_loaders import WebBaseLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.embeddings.ollama import OllamaEmbeddings
import ollama
from IPython.display import Markdown

llm_model = "llama3.2"

# Function to load, split, and retrieve documents
def load_and_retrieve_docs(urls):
    loaders = [WebBaseLoader(web_paths=(url,), bs_kwargs=dict()) for url in urls]
    docs = []
    for loader in loaders:
        docs.extend(loader.load())  
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
    splits = text_splitter.split_documents(docs)
    embeddings = OllamaEmbeddings(model=llm_model)
    vectorstore = Chroma.from_documents(documents=splits, embedding=embeddings)
    return vectorstore.as_retriever()

# three URLs
urls = [
    "https://www.ibm.com/topics/large-language-models",
    "https://en.wikipedia.org/wiki/Natural_language_processing",
    "https://www.ibm.com/cloud/what-is-cloud-computing"
]


retriever = load_and_retrieve_docs(urls)


def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)


# Define the Ollama LLM function
def ollama_llm(question, context):
    formatted_prompt = f"Question: {question}\n\nContext: {context}"
    response = ollama.chat(model='llama3.2', messages=[{'role': 'user', 'content': formatted_prompt}])
    return response['message']['content']

# Define the RAG chain
def rag_chain(question):
    retrieved_docs = retriever.invoke(question)
    formatted_context = format_docs(retrieved_docs)
    return ollama_llm(question, formatted_context)


questions = [
    "What are IBM's solutions related to LLMs?",
    "What are the primary tasks in Natural Language Processing?",
    "What are the benefits of cloud computing?"
]

for question in questions:
    result = rag_chain(question)
    print(f"Question: {question}\n")
    display(Markdown(result))
    print("\n---\n")
# Out:
# Question: What are IBM's solutions related to LLMs?
# IBM's solutions related to Large Language Models (LLMs) include:
#
# 1. Granite model series on watsonx.ai: This is IBM's generative AI backbone that powers other IBM products such as watsonx Assistant and watsonx Orchestrate.
# 2. watsonx Assistant: This product uses the Granite model series to provide conversational AI capabilities.
# 3. watsonx Orchestrate: This product also leverages the Granite model series for its natural language processing (NLP) and machine learning (ML) capabilities.
#
# These solutions demonstrate IBM's investment in LLM technology and its ability to integrate it into various products and services, providing organizations with a robust platform for AI-driven applications.
# ---
#
# Question: What are the primary tasks in Natural Language Processing?
# The primary tasks in Natural Language Processing (NLP) mentioned in the provided context are:
#
# 1. Speech recognition
# 2. Text classification
# ...

# %% [markdown]
# He can give me the correct answer, but  if answer is not in the documentation he cannot.

# %%
# Exercise 12 
# Plot training and validation accuracy
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linestyle='--')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Plot training and validation loss
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss', linestyle='--')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
I think llm can help us find word-to-word relationships，and get a better answer.

# %% [markdown]
# # Exercise 13
# In our training zero-shot, 1-shot and 5-shot have almost same result，I think if we give more shot ,the result will be better.
